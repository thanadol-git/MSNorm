# %% [markdown]
# # Dataset for normalization

# %%
# Import all necessary libraries

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
# Read all file ending with .sdrf.tsv in plasma_serum folder
files = [f for f in os.listdir('plasma_msstats') if f.endswith('.sdrf.tsv')]

# Read all files
dfs = [pd.read_csv(f'plasma_msstats/{f}', sep='\t') for f in files]

# Concatenate all dataframes   

df

# %%
# Write a function to summarise the data 

def summarise_data(df):
    # Print out sample number
    try:
        print(f"Number of samples: {df.shape[0]}")
    except Exception:
        pass

    # Print out instrument name
    try:
        print(f"Instrument: {df['comment[instrument]'].unique()}")
    except Exception:
        pass

    # Print out modification
    try:
        print(f"Modification: {df['comment[modification parameter]'].unique()}")
    except Exception:
        pass

    # Print out NCE
    try:
        print(f"NCE: {df['comment[collision energy]'].unique()}")
    except Exception:
        pass

    # Print unique items in each factor value column
    try:
        factor_cols = df.columns[df.columns.str.startswith('factor value')]
        for col in factor_cols:
            try:
                unique_items = df[col].dropna().unique()
                print(f"Unique items in {col}: {unique_items}")
            except Exception:
                pass
    except Exception:
        pass
summarise_data(dfs[0])

# %%
# Write for look for all diles in dfs and summarise the data
for df in dfs:
    summarise_data(df)
