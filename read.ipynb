# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import os

# %%
# Read akkfile with sufffix 'msstats_in.csv' in the folder 'plasma_msstats'
files = [f for f in os.listdir('plasma_msstats') if f.endswith('msstats_in.csv')]

# Read all files
dfs_msstats = [pd.read_csv(f'plasma_msstats/{f}', sep=',') for f in files]

# %% [markdown]
# dfs_msstats[0]

# %%
test = dfs_msstats[0]

# %%
# plot boxplot of Intensity by PeptideSequence, grouped by ProteinName
sns.boxplot(data=test, x='ProteinName', y='Intensity', hue='PeptideSequence')
plt.show()
